# %%
from datetime import datetime

dates = [
    "Wednesday, October 2, 2002",
    "Friday, 11.10.13",
    "Thursday, 18 August 1977"
]

formats = [
    "%A, %B %d, %Y", 
    "%A, %d.%m.%y",   
    "%A, %d %B %Y"     
]

for date_str, date_format in zip(dates, formats):
    dt = datetime.strptime(date_str, date_format)
    print(dt)
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00

# %%
from datetime import datetime, timedelta

def date_range(start_date, end_date):
    try:
        start = datetime.strptime(start_date, "%Y-%m-%d")
        end = datetime.strptime(end_date, "%Y-%m-%d")
    except ValueError:
        return []

    if start > end:
        return []

    dates = []
    current = start

    while current <= end:
        dates.append(current.strftime("%Y-%m-%d"))
        current += timedelta(days=1)

    return dates

start_date = "2026-01-01"
end_date = "2026-01-12"

result = date_range(start_date, end_date)
print(result)
# Out:
# ['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04', '2026-01-05', '2026-01-06', '2026-01-07', '2026-01-08', '2026-01-09', '2026-01-10', '2026-01-11', '2026-01-12']
